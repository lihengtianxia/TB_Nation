# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn-poster')

import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
#     rolmean = pd.rolling_mean(timeseries, window=12)
    rolmean = timeseries.rolling(window=12,center=False).mean()
#     rolstd = pd.rolling_std(timeseries, window=12)
    rolstd = timeseries.rolling(window=12,center=False).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(8, 6))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='BIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
datasets = pd.read_excel('TB_nation.xlsx',index_col='Date')
datasets_pred = datasets[datasets.index>='2014-01-1']
datasets = datasets[datasets.index<'2014-01-01']
datasets.shape
# Out:
# (108, 7)

# %%
datasets['log_natural'] = datasets['Incidence_rate'].apply(lambda x: np.log(x))

# %%
test_stationarity(datasets.log_natural.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.180309
# p-value                         0.682008
# #Lags Used                     12.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (10%)           -2.583275
# Critical Value (5%)            -2.892480
# dtype: float64

# %%
datasets['first_diff'] = datasets.log_natural - datasets.log_natural.shift(1)
test_stationarity(datasets.first_diff.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.544143
# p-value                         0.000002
# #Lags Used                     11.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (10%)           -2.583275
# Critical Value (5%)            -2.892480
# dtype: float64

# %%
fig = plt.figure(figsize=(10,12))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(datasets.first_diff.iloc[1:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(datasets.first_diff.iloc[1:], lags=40, ax=ax2)
# fig.savefig('Autocorrection.png',dpi=600)

# %%
mod = sm.tsa.SARIMAX(datasets.log_natural, trend='n', order=(1,1,1), seasonal_order=(1,0,0,12))
results = mod.fit()
print(results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                        log_natural   No. Observations:                  108
# Model:             SARIMAX(1, 1, 1)x(1, 0, 0, 12)   Log Likelihood                 103.059
# Date:                            Fri, 17 Mar 2017   AIC                           -198.118
# Time:                                    13:52:41   BIC                           -187.389
# Sample:                                01-01-2005   HQIC                          -193.768
#                                      - 12-01-2013
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4331      0.073      5.902      0.000       0.289       0.577
# ma.L1         -0.9672      0.022    -44.855      0.000      -1.009      -0.925
# ar.S.L12       0.8910      0.022     40.990      0.000       0.848       0.934
# sigma2         0.0071      0.001     13.293      0.000       0.006       0.008
# ===================================================================================
# Ljung-Box (Q):                       47.33   Jarque-Bera (JB):               141.10
# Prob(Q):                              0.20   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.10   Skew:                             0.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Plot

# %%
datasets['forecast_log'] = results.predict(start = 2, end= 131, dynamic= False)  
datasets[['log_natural', 'forecast_log']].plot(figsize=(8, 6))

# %%
dta = pd.concat([datasets, datasets_pred])[['Incidence_rate','log_natural','forecast_log','Year','Month']]
dta['forecast_log'] = results.predict(start=13,end=131,dynamic=False)
dta['forecast'] = dta['forecast_log'].apply(lambda x: np.exp(x))
dta.tail(12)
# Out:
#             Incidence_rate  log_natural  forecast_log  Year  Month  forecast
# Date
# 2014-01-01        6.576894          NaN      1.854344  2014      1  6.387505
# 2014-02-01        5.693240          NaN      1.712828  2014      2  5.544619
# 2014-03-01        6.233394          NaN      1.803523  2014      3  6.070997
# 2014-04-01        6.017185          NaN      1.792246  2014      4  6.002919
# 2014-05-01        5.868642          NaN      1.764015  2014      5  5.835820
# 2014-06-01        5.635166          NaN      1.694791  2014      6  5.445509
# 2014-07-01        5.505367          NaN      1.683201  2014      7  5.382757
# 2014-08-01        5.249826          NaN      1.673422  2014      8  5.330376
# 2014-09-01        4.950454          NaN      1.615279  2014      9  5.029291
# 2014-10-01        5.051475          NaN      1.633128  2014     10  5.119866
# 2014-11-01        4.423730          NaN      1.527468  2014     11  4.606496
# 2014-12-01        4.423435          NaN      1.492478  2014     12  4.448103

# %%
dta['forecast_log'] = results.predict(start=2,end=131,dynamic=False)
dta['forecast'] = dta['forecast_log'].apply(lambda x: np.exp(x))
dta[['Incidence_rate','forecast']].plot(figsize=(8, 6))

# %%
dta['error_ARIMA'] = dta['Incidence_rate']-dta['forecast']
dta['error_ARIMA'].plot(figsize=(8,6))
sum(abs(dta['error_ARIMA'].dropna()))
# Out:
# 46.059095155315859

# %%
fig = plt.figure(figsize=(8,12))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.error_ARIMA.iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta.error_ARIMA.iloc[13:], lags=40, ax=ax2)
# fig.savefig('Autocorrection.png',dpi=600)

# %%
dta.to_excel('data_SARIMA.xlsx')
