# %% [markdown]
# ## First Difference

# %% [markdown]
# ### Test of stationarity

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
#     rolmean = pd.rolling_mean(timeseries, window=12)
    rolmean = timeseries.rolling(window=12,center=False).mean()
#     rolstd = pd.rolling_std(timeseries, window=12)
    rolstd = timeseries.rolling(window=12,center=False).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='BIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
datasets = pd.read_excel('TB_nation.xlsx',index_col='Date')
datasets_pred = datasets[datasets.index>='2014-01-1']
datasets = datasets[datasets.index<'2014-01-01']
datasets.shape
# Out:
# (108, 7)

# %%
datasets.head()
# Out:
#               Area  Incidence  Death  Incidence_rate  Death_rate  Year  Month
# Date
# 2005-01-01  全    国     114194    143        8.784966    0.011001  2005      1
# 2005-02-01  全    国      87112    201        6.701542    0.015463  2005      2
# 2005-03-01  全    国     130134    281       10.011233    0.021617  2005      3
# 2005-04-01  全    国     133924    374       10.302798    0.028772  2005      4
# 2005-05-01  全    国     121326    388        9.333632    0.029849  2005      5

# %%
datasets.describe()
# Out:
#            Incidence       Death  Incidence_rate  Death_rate         Year  \
# count     108.000000  108.000000      108.000000  108.000000   108.000000
# mean    88869.296296  259.935185        6.704184    0.019607  2009.000000
# std     19018.858884   67.609831        1.484929    0.005221     2.594026
# min     42399.000000  103.000000        3.242605    0.007795  2005.000000
# 25%     75495.000000  210.750000        5.606035    0.015862  2007.000000
# 50%     88201.000000  250.000000        6.648970    0.018797  2009.000000
# 75%    100166.000000  295.250000        7.627035    0.022348  2011.000000
# max    133924.000000  433.000000       10.302798    0.032605  2013.000000
#
#             Month
# count  108.000000
# mean     6.500000
# std      3.468146
# min      1.000000
# 25%      3.750000
# 50%      6.500000
# 75%      9.250000
# max     12.000000

# %% [markdown]
# ### 原始序列的平稳性检验

# %%
test_stationarity(datasets['Incidence_rate'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.380061
# p-value                         0.591797
# #Lags Used                     12.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64

# %% [markdown]
# ### First difference

# %%
datasets['first_diff'] = datasets.Incidence_rate - datasets.Incidence_rate.shift(1)
test_stationarity(datasets.first_diff.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.129699
# p-value                         0.000012
# #Lags Used                     11.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(datasets.first_diff.iloc[1:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(datasets.first_diff.iloc[1:], lags=40, ax=ax2)

# %% [markdown]
# ### Bulid Model

# %%
mod = sm.tsa.SARIMAX(datasets.Incidence_rate, trend='n', order=(1,1,1), seasonal_order=(1,0,0,12))
results = mod.fit()
print(results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                     Incidence_rate   No. Observations:                  108
# Model:             SARIMAX(1, 1, 1)x(1, 0, 0, 12)   Log Likelihood                 -91.080
# Date:                            Sat, 18 Mar 2017   AIC                            190.161
# Time:                                    16:24:15   BIC                            200.889
# Sample:                                01-01-2005   HQIC                           194.511
#                                      - 12-01-2013
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4968      0.083      5.997      0.000       0.334       0.659
# ma.L1         -0.9689      0.018    -53.071      0.000      -1.005      -0.933
# ar.S.L12       0.9049      0.019     46.977      0.000       0.867       0.943
# sigma2         0.2657      0.026     10.255      0.000       0.215       0.316
# ===================================================================================
# Ljung-Box (Q):                       53.87   Jarque-Bera (JB):                54.77
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.09   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Plot

# %%
datasets['forecast'] = results.predict(start = 1, end= 131, dynamic= False)  
datasets[['Incidence_rate', 'forecast']].plot(figsize=(12, 8))

# %%
dta = pd.concat([datasets, datasets_pred])[['Death','Death_rate','Incidence','Incidence_rate','forecast','Year','Month']]
dta['forecast'] = results.predict(start=1,end=131,dynamic=False)
dta.tail(13)
# Out:
#             Death  Death_rate  Incidence  Incidence_rate  forecast  Year  \
# Date
# 2013-12-01    195    0.014401      60399        4.460651  4.210545  2013
# 2014-01-01    189    0.013947      89128        6.576894  6.405340  2014
# 2014-02-01    178    0.013135      77153        5.693240  5.535652  2014
# 2014-03-01    214    0.015791      84473        6.233394  6.082717  2014
# 2014-04-01    230    0.016972      81543        6.017185  6.008232  2014
# 2014-05-01    212    0.015644      79530        5.868642  5.829827  2014
# 2014-06-01    182    0.013430      76366        5.635166  5.419090  2014
# 2014-07-01    184    0.013578      74607        5.505367  5.352578  2014
# 2014-08-01    188    0.013873      71144        5.249826  5.297408  2014
# 2014-09-01    187    0.013799      67087        4.950454  4.984655  2014
# 2014-10-01    157    0.011585      68456        5.051475  5.078231  2014
# 2014-11-01    166    0.012249      59949        4.423730  4.549531  2014
# 2014-12-01    153    0.011290      59945        4.423435  4.387802  2014
#
#             Month
# Date
# 2013-12-01     12
# 2014-01-01      1
# 2014-02-01      2
# 2014-03-01      3
# 2014-04-01      4
# 2014-05-01      5
# 2014-06-01      6
# 2014-07-01      7
# 2014-08-01      8
# 2014-09-01      9
# 2014-10-01     10
# 2014-11-01     11
# 2014-12-01     12

# %%
dta['forecast'] = results.predict(start = 2, end= 131, dynamic= False)  
dta[['Incidence_rate','forecast']].plot(figsize=(12, 8))

# %%
dta['error_ARIMA'] = dta['forecast']-dta['Incidence_rate']
dta['error_ARIMA'].plot(figsize=(12,8))
sum(dta['error_ARIMA'].dropna())
# Out:
# 7.6963771441320121

# %%
fig = plt.figure(figsize=(8,12))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.error_ARIMA.iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta.error_ARIMA.iloc[13:], lags=40, ax=ax2)
# fig.savefig('Autocorrection.png',dpi=600)

# %%
dta.to_excel('Difference.xlsx')
